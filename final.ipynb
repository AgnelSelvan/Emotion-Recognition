# %%
from time import sleep
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import numpy as np 
import cv2
import sys

# sys.path.append('/home/agnel/Agnel/ML/Emotion and Gender Detector/')
from trainModel import *

classifier = load_model('./TrainedModel/4(57)/Emotion_detector.h5')

face_classfier = cv2.CascadeClassifier('/home/agnel/Agnel/files/HaarCascade/haarcascade_frontalface_default.xml')

def face_detector(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_classfier.detectMultiScale(gray, 1.3, 5)

    if faces is ():
        return (0, 0, 0, 0), np.zeros((48, 48), np.uint8), img
    
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x-50, y-50), (x+w, y+h), (255, 0, 0), 2)
        roi_gray = gray[y:y+h, x:x+w]

    try:
        roi_gray = cv2.resize(roi_gray, (48, 48), interpolation=cv2.INTER_AREA)
    except:
        return (x, y, w, h), np.zeros((48, 48), np.uint8), img
    
    return (x, y, w, h), roi_gray, img

cap = cv2.VideoCapture('./video.mp4')

while True:

    ret, frame = cap.read()
    rect, face, image = face_detector(frame)
    if np.sum([face]) != 0.0:
        roi = face.astype("float") / 255.0
        roi = img_to_array(roi)
        roi = np.expand_dims(roi, axis=0)

        preds = classifier.predict(roi)[0]
        label = class_labels[preds.argmax()]
        label_position = (rect[0] + int((rect[1]/2)), rect[2] + 25)
        cv2.putText(image, label, label_position, cv2.FONT_HERSHEY_COMPLEX, 2, (255, 0, 0), 2)
    
    else:
        cv2.putText(image, "No Face found", (20, 60), cv2.FONT_HERSHEY_COMPLEX, 2, (0, 255, 0), 2)
    
    cv2.imshow('All', image)
    if cv2.waitKey(1) == 13:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-1-69b41fa89d7e> in <module>
#       1 from time import sleep
# ----> 2 from keras.preprocessing.image import img_to_array
#       3 from keras.models import load_model
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\keras\__init__.py in <module>
#       2 try:
# ----> 3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\tensorflow\__init__.py in <module>
#      54 from ._api.v2 import bitwise
# ---> 55 from ._api.v2 import compat
#      56 from ._api.v2 import config
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\tensorflow\_api\v2\compat\__init__.py in <module>
#      38
# ---> 39 from . import v1
#      40 from . import v2
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\tensorflow\_api\v2\compat\v1\__init__.py in <module>
#      33 from . import bitwise
# ---> 34 from . import compat
#      35 from . import config
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py in <module>
#      38
# ---> 39 from . import v1
#      40 from . import v2
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\v1\__init__.py in <module>
#      50 from tensorflow._api.v2.compat.v1 import linalg
# ---> 51 from tensorflow._api.v2.compat.v1 import lite
#      52 from tensorflow._api.v2.compat.v1 import logging
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\tensorflow\_api\v2\compat\v1\lite\__init__.py in <module>
#      10 from . import constants
# ---> 11 from . import experimental
#      12 from tensorflow.lite.python.lite import Interpreter
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\tensorflow\_api\v2\compat\v1\lite\experimental\__init__.py in <module>
#       9
# ---> 10 from . import nn
#      11 from tensorflow.lite.python.lite import convert_op_hints_to_stubs
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\tensorflow\_api\v2\compat\v1\lite\experimental\nn\__init__.py in <module>
#       9
# ---> 10 from tensorflow.lite.python.lite import TFLiteLSTMCell
#      11 from tensorflow.lite.python.lite import TfLiteRNNCell
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\tensorflow\lite\python\lite.py in <module>
#      39 from tensorflow.lite.python import lite_constants as constants
# ---> 40 from tensorflow.lite.python.convert import build_toco_convert_protos  # pylint: disable=unused-import
#      41 from tensorflow.lite.python.convert import convert_saved_model as _convert_saved_model
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\tensorflow\lite\python\convert.py in <module>
#      21
# ---> 22 import distutils.spawn
#      23 import enum  # pylint: disable=g-bad-import-order
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\importlib\_bootstrap_external.py in get_code(self, fullname)
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\importlib\_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         # in the engines. This should return a list of strings.
# -> 2045                         stb = value._render_traceback_()
#    2046                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1169             # (5 blanks lines) where none should be returned.
# -> 1170             return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#    1171         except UnicodeDecodeError:
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in wrapped(*args, **kwargs)
#     315         try:
# --> 316             return f(*args, **kwargs)
#     317         finally:
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in _fixed_getinnerframes(etb, context, tb_offset)
#     349
# --> 350     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#     351     # If the error is at the console, don't build any context, since it would
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\inspect.py in getinnerframes(tb, context)
#    1501     while tb:
# -> 1502         frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#    1503         framelist.append(FrameInfo(*frameinfo))
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\inspect.py in getframeinfo(frame, context)
#    1459
# -> 1460     filename = getsourcefile(frame) or getfile(frame)
#    1461     if context > 0:
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\inspect.py in getsourcefile(object)
#     695     # only return a non-existent filename if the module has a PEP 302 loader
# --> 696     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#     697         return filename
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\inspect.py in getmodule(object, _filename)
#     738             _filesbymodname[modname] = f
# --> 739             f = getabsfile(module)
#     740             # Always map to the name the module knows itself by
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\inspect.py in getabsfile(object, _filename)
#     707     if _filename is None:
# --> 708         _filename = getsourcefile(object) or getfile(object)
#     709     return os.path.normcase(os.path.abspath(_filename))
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\inspect.py in getsourcefile(object)
#     692         return None
# --> 693     if os.path.exists(filename):
#     694         return filename
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\genericpath.py in exists(path)
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2047                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2048                                             value, tb, tb_offset=tb_offset)
#    2049
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1436         return FormattedTB.structured_traceback(
# -> 1437             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1438
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1336             return VerboseTB.structured_traceback(
# -> 1337                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1338             )
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1193         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1194                                                                tb_offset)
#    1195
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1147         head = self.prepare_header(etype, self.long_header)
# -> 1148         records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#    1149
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1184             inspect_error()
# -> 1185             traceback.print_exc(file=self.ostream)
#    1186             info('\nUnfortunately, your original traceback can not be constructed.\n')
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\traceback.py in print_exc(limit, file, chain)
#     162     """Shorthand for 'print_exception(*sys.exc_info(), limit, file)'."""
# --> 163     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#     164
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\traceback.py in print_exception(etype, value, tb, limit, file, chain)
#     103     for line in TracebackException(
# --> 104             type(value), value, tb, limit=limit).format(chain=chain):
#     105         print(line, file=file, end="")
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\traceback.py in __init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     507             walk_tb(exc_traceback), limit=limit, lookup_lines=lookup_lines,
# --> 508             capture_locals=capture_locals)
#     509         self.exc_type = exc_type
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     362             for f in result:
# --> 363                 f.line
#     364         return result
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\traceback.py in line(self)
#     284         if self._line is None:
# --> 285             self._line = linecache.getline(self.filename, self.lineno).strip()
#     286         return self._line
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\linecache.py in getline(filename, lineno, module_globals)
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\linecache.py in getlines(filename, module_globals)
#      46     try:
# ---> 47         return updatecache(filename, module_globals)
#      48     except MemoryError:
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\linecache.py in updatecache(filename, module_globals)
#     135     try:
# --> 136         with tokenize.open(fullname) as fp:
#     137             lines = fp.readlines()
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\tokenize.py in open(filename)
#     446     """
# --> 447     buffer = _builtin_open(filename, 'rb')
#     448     try:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2058
#    2059         except KeyboardInterrupt:
# -> 2060             print('\n' + self.get_exception_only(), file=sys.stderr)
#    2061
#    2062     def _showtraceback(self, etype, evalue, stb):
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py in get_exception_only(self, exc_tuple)
#    2003         """
#    2004         etype, value, tb = self._get_exc_info(exc_tuple)
# -> 2005         msg = traceback.format_exception_only(etype, value)
#    2006         return ''.join(msg)
#    2007
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\traceback.py in format_exception_only(etype, value)
#     138
#     139     """
# --> 140     return list(TracebackException(etype, value, None).format_exception_only())
#     141
#     142
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\traceback.py in __init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     519             self.msg = exc_value.msg
#     520         if lookup_lines:
# --> 521             self._load_lines()
#     522
#     523     @classmethod
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\traceback.py in _load_lines(self)
#     531             frame.line
#     532         if self.__context__:
# --> 533             self.__context__._load_lines()
#     534         if self.__cause__:
#     535             self.__cause__._load_lines()
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\traceback.py in _load_lines(self)
#     529         """Private API. force all lines in the stack to be loaded."""
#     530         for frame in self.stack:
# --> 531             frame.line
#     532         if self.__context__:
#     533             self.__context__._load_lines()
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\traceback.py in line(self)
#     283     def line(self):
#     284         if self._line is None:
# --> 285             self._line = linecache.getline(self.filename, self.lineno).strip()
#     286         return self._line
#     287
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\linecache.py in getline(filename, lineno, module_globals)
#      14
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#      18         return lines[lineno-1]
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\linecache.py in getlines(filename, module_globals)
#      45
#      46     try:
# ---> 47         return updatecache(filename, module_globals)
#      48     except MemoryError:
#      49         clearcache()
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\linecache.py in updatecache(filename, module_globals)
#     134             return []
#     135     try:
# --> 136         with tokenize.open(fullname) as fp:
#     137             lines = fp.readlines()
#     138     except OSError:
#
# c:\users\agnelselvan\appdata\local\programs\python\python37\lib\tokenize.py in open(filename)
#     445     detect_encoding().
#     446     """
# --> 447     buffer = _builtin_open(filename, 'rb')
#     448     try:
#     449         encoding, lines = detect_encoding(buffer.readline)
#
# KeyboardInterrupt:
